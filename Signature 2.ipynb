# %%
import shutil
import os, sys, random
from glob import glob
import pandas as pd
from shutil import copyfile
import pandas as pd
from sklearn import preprocessing, model_selection
import matplotlib.pyplot as plt
from matplotlib import patches
import numpy as np
import os
# %matplotlib inline

# %%
# !git clone  'https://github.com/ultralytics/yolov5.git'
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16773, done.
# remote: Counting objects: 100% (314/314), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 16773 (delta 171), reused 160 (delta 83), pack-reused 16459
# Receiving objects: 100% (16773/16773), 15.49 MiB | 28.68 MiB/s, done.
# Resolving deltas: 100% (11474/11474), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Flashaid/Signature/tobacco_yolo_format.zip" -d "/content/yolov5"
# Out:
# Archive:  /content/drive/MyDrive/Flashaid/Signature/tobacco_yolo_format.zip
#    creating: /content/yolov5/tobacco_yolo_format/images/
#    creating: /content/yolov5/tobacco_yolo_format/images/train/
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/aah97e00-page02_1.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/aah97e00-page02_2.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/aam09c00.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/acr64d00.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/adh36e00_1.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/adh36e00_2.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/adh36e00-page2_1.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/adh36e00-page2_2.jpg
#   inflating: /content/yolov5/tobacco_yolo_format/images/train/adn64a00-page02_3.jpg
# ...

# %%
#import os
#os.listdir()
# Out:
# ['.config', 'yolov5', 'tobacco_data.yaml', 'sample_data']

# %%
# !sed -i 's/PyYAML>=5.3.1/PyYAML==5.4.1/g' yolov5/requirements.txt

# %%
#!pip install -qr 'yolov5/requirements.txt'

# %%
# Setting the model parameters
#shutil.copyfile('/content/tobacco_data.yaml', 'yolov5/tobacco_data.yaml') # copying the custom_dataset.yaml file to the project repo
# setting number of classes to two (since the tobacco 800 dataset contains 2 classes, Logo & Signature)
# !sed -i 's/nc: 80/nc: 2/g' ./yolov5/models/yolov5x.yaml
# !cat yolov5/tobacco_data.yaml
# Out:
# train: tobacco_yolo_format/images/train
# val: tobacco_yolo_format/images/valid
#
# nc: 2
# names: ['DLLogo', 'DLSignature']

# %%
#!python yolov5/train.py --img 640 --batch 16 --epochs 300 --data yolov5/tobacco_data.yaml --cfg yolov5/models/yolov5x.yaml --name Tobacco-run
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.1/800.1 kB 7.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
#!python yolov5/train.py --img 640 --batch 16 --epochs 300 --data yolov5/tobacco_data.yaml --cfg yolov5/models/yolov5x.yaml --name Tobacco-run --resume --patience 10
# Out:
# 2024-07-12 09:40:31.105089: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-12 09:40:31.105135: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-12 09:40:31.106550: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 300 --data yolov5/tobacco_data.yaml --cfg yolov5/models/yolov5x.yaml --name Tobacco-run --resume /content/drive/MyDrive/Flashaid/Signature/last.pt --patience 10
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 kB 10.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !python yolov5/detect.py --source yolov5/tobacco_yolo_format/images/valid/ --weights '/content/yolov5/runs/train/Tobacco-run/weights/last.pt' \
 --hide-labels --hide-conf --classes 1 --line-thickness 2
# Out:
# detect: weights=['/content/yolov5/runs/train/Tobacco-run/weights/last.pt'], source=yolov5/tobacco_yolo_format/images/valid/, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=[1], agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=2, hide_labels=True, hide_conf=True, half=False, dnn=False, vid_stride=1
# requirements: Ultralytics requirements ['pillow>=10.3.0', 'PyYAML==5.4.1', 'requests>=2.32.0'] not found, attempting AutoUpdate...
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# ...

# %%
# !zip -r /content/drive/MyDrive/Flashaid/Signature/detect.zip /content/yolov5/runs/detect
# Out:
#   adding: content/yolov5/runs/detect/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/rsj41f00-page02_2.jpg (deflated 12%)
#   adding: content/yolov5/runs/detect/exp/aex05f00_1.jpg (deflated 9%)
#   adding: content/yolov5/runs/detect/exp/djz54f00.jpg (deflated 11%)
#   adding: content/yolov5/runs/detect/exp/chw80e00_1.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/fwe69c00.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/waq00e00.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/cxk72e00-page03_3.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/huz50e00_1.jpg (deflated 5%)
#   adding: content/yolov5/runs/detect/exp/nlu01f00.jpg (deflated 5%)
#   adding: content/yolov5/runs/detect/exp/vad45f00-page03_1.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/nrg54f00-page02_1.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/zkd43f00_3.jpg (deflated 6%)
# ...
